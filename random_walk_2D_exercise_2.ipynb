# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# Random walk - Probability forward , backward , left , right = 40% 10% 25% 25% <br/>
# distance covered for forward , backward , left , right = 75cm , 45cm , 60cm , 60cm

# %%
# Random walk - Probability forward , backward , left , right = 40% 10% 25% 25%
random_walk_probabilities = [0.4 , 0.1 , 0.25 , 0.25]

# calculate cumulative probabilities
cumulative_probabilities = [random_walk_probabilities[0]]
for i in range(1, len(random_walk_probabilities)):
    cumulative_probabilities.append(cumulative_probabilities[i-1] + random_walk_probabilities[i])

# generate random digit assignments
random_walk_random_digits = []
count = 0
for i in range(len(random_walk_probabilities)):
    random_walk_random_digits.append([])
    for j in range(int(random_walk_probabilities[i]*100)): 
        random_walk_random_digits[i].append(count)
        count += 1
        

# for i in range(len(cumulative_probabilities)):
#     print(f"{cumulative_probabilities[i]:.2f}")

# %%
import random
import math
import matplotlib.pyplot as plt

# set up the distances in the x and y axes
up, down, left, right = 75, 45, 60, 60

# initialize the starting point as (0,0)
x, y = 0, 0

# create empty lists to store the x and y coordinates of the movement
x_list = [x]
y_list = [y]

# generate a random direction and move accordingly
for i in range(50):  # move 50 times
    step = random.randint(0,99)
    global direction
    
    # find direction from generated random num
    for j in range(len(random_walk_random_digits)):
        if step in random_walk_random_digits[j]:
            if j == 0:
                direction = "forward"
            if j == 1:
                direction = "backward"
            if j == 2:
                direction = "left"
            if j == 3:
                direction = "right"
            break
    
    if direction == 'forward':
        y += up
    elif direction == 'backward':
        y -= down
    elif direction == 'left':
        x -= left
    else:
        x += right
    x_list.append(x)
    y_list.append(y)

# calculate the total distance covered
distance = math.sqrt(x**2 + y**2)

# create a scatter plot with green points
plt.scatter(x_list, y_list , color='green')
# create a line plot with blue lines connecting the points
plt.plot(x_list, y_list , color='blue')
# add the first point as a cyan point
plt.scatter(x_list[0], y_list[0], color='cyan')
# add the last point as a pink point
plt.scatter(x_list[-1], y_list[-1], color='red')
plt.title(f"Total Distance Covered: {distance:.2f} cm")
plt.xlabel("X-axis (cm)")
plt.ylabel("Y-axis (cm)")
plt.show()

# %% [markdown]
# ### Extra

# %%
import random
import math
import matplotlib.pyplot as plt

# set up the distances in the x and y axes
up, down, left, right = 75, 45, 60, 60

# set up the number of simulations and steps
num_simulations = 1000
num_steps = 50

# create empty lists to store the x and y coordinates of the final position of each simulation
x_final = []
y_final = []

# simulate for each simulation
for i in range(num_simulations):
    # initialize the starting point as (0,0)
    x, y = 0, 0
    # simulate for each step
    for j in range(num_steps):
        direction = random.choice(['up', 'down', 'left', 'right'])
        if direction == 'up':
            y += up
        elif direction == 'down':
            y -= down
        elif direction == 'left':
            x -= left
        else:
            x += right
    x_final.append(x)
    y_final.append(y)

# plot the final position of each simulation on a scatter plot
plt.scatter(x_final, y_final)
plt.title(f"Final Positions after {num_steps} Steps for {num_simulations} Simulations")
plt.xlabel("X-axis (cm)")
plt.ylabel("Y-axis (cm)")
plt.show()

# %%
import random
import math
import matplotlib.pyplot as plt

# set up the distances in the x and y axes
up, down, left, right = 75, 45, 60, 60

# set up the number of simulations and steps
num_simulations = 1000
num_steps = 50

# create empty lists to store the x and y coordinates of the final position of each simulation
x_final = []
y_final = []

# simulate for each simulation
for i in range(num_simulations):
    # initialize the starting point as (0,0)
    x, y = 0, 0
    # simulate for each step
    for j in range(num_steps):
        direction = random.choice(['up', 'down', 'left', 'right'])
        if direction == 'up':
            y += up
        elif direction == 'down':
            y -= down
        elif direction == 'left':
            x -= left
        else:
            x += right
    x_final.append(x)
    y_final.append(y)

# plot the final position of each simulation on a scatter plot
fig, ax = plt.subplots()
ax.scatter(x_final, y_final)
ax.set_title(f"Final Positions after {num_steps} Steps for {num_simulations} Simulations")

# add a circle to show the boundary of the area covered by the simulated movements
radius = max(abs(max(x_final)), abs(min(x_final)), abs(max(y_final)), abs(min(y_final)))
circle = plt.Circle((0, 0), radius, color='r', fill=False)
ax.add_artist(circle)

# set the x and y limits of the plot to include the circle
ax.set_xlim(-radius, radius)
ax.set_ylim(-radius, radius)

# add axis labels
ax.set_xlabel("X-axis (cm)")
ax.set_ylabel("Y-axis (cm)")

plt.show()
